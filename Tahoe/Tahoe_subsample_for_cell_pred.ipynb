# %% [markdown]
# # Subsampling of Tahoe Dataset
# ## Predicting perturbation responses for unseen cell-types (context transfer)

# %% [markdown]
# # Imports

# %%
import io
import pandas as pd
import scanpy as sc
import pyarrow.dataset as ds
import gcsfs
import os
import numpy as np
import ast

# %% [markdown]
# # Functions

# %%
# List Files in Google Cloud Storage Bucket

def print_gc_files(fs):
    # List the top‐level contents of the bucket
    print(fs.ls('arc-ctc-tahoe100'))

    # Drill down into a folder:
    print(fs.ls('arc-ctc-tahoe100/2025-02-25'))

    # List everything recursively:
    all_files = fs.find('arc-ctc-tahoe100')
    print(len(all_files), "items found")
    for file in all_files:
        print(file)


# Calculate Total Remote File Size in GCS

def calc_remote_file_size(fs, h5ad_file):
    all_paths = fs.find(h5ad_file)

    # Sum up file sizes
    total_bytes = 0
    for path in all_paths:
        print(path)
        info = fs.info(path)
        if info.get('type') == 'file':
            total_bytes += info.get('size', 0)

    # Print result in bytes and GB
    print(f"Total size: {total_bytes:,} bytes")
    print(f"Which is roughly {total_bytes/1e9:.2f} GB")
    
# Parse Drug Condition Identifier   

def parse_condition(s):
    parsed = ast.literal_eval(s)
    if len(parsed) == 0:
        raise ValueError(f"Condition {s} is empty")
    compound, dose, unit = parsed[0]
    x = f"{compound}_{dose}{unit}"
    x = x.replace('.', '')
    return x

# Extract Numerical Dose from Condition String

def get_dose_from_condition(s):
    parsed = ast.literal_eval(s)
    if len(parsed) == 0:
        raise ValueError(f"Condition {s} is empty")
    compound, dose, unit = parsed[0]
    return float(dose)

# %% [markdown]
# # Read the data and subsample

# %%
# Download the h5ad file from google storage # mounts Google Cloud Storage via gcsfs and downloads the file
local_file  = "plate9_full.h5ad"
if not os.path.exists(local_file):
    # Initialize GCS file system for reading data from GCS
    fs = gcsfs.GCSFileSystem()
    
    # File to Download and use
    h5ad_file = 'arc-ctc-tahoe100/2025-02-25/h5ad/plate9_filt_Vevo_Tahoe100M_WServicesFrom_ParseGigalab.h5ad'
    
    # print_gc_files(fs)
    # calc_remote_file_size(fs, h5ad_file)

    print(f"Downloading {h5ad_file} → {local_file} …")
    fs.get(h5ad_file, local_file)
    print("Download complete.")
else:
    print(f"Local file '{local_file}' already exists; skipping download.")    # Otherwise, if the backed file already exists, it skips the download.


# Open in backed mode (only obs. and var. loaded into RAM, the rest of the expression matrix is on the disc)
print("Reading all data...")
adata_full = sc.read_h5ad(local_file, backed="r")  
print("-> Total cells on Plate 9:", adata_full.n_obs)  


# Explore observation metadata 
print(adata_full.obs.head())
print(adata_full.obs.columns)

#  Identify control vs. treated cells
print("------ All drug labels -------")
all_drug_labels = adata_full.obs['drug'].unique()
# for index, label in enumerate(all_drug_labels):
#     print(f"{index+1}) {label}")

# Build a mask that picks up either 'DMSO_TF' or any plain 'DMSO':
ctrl_mask = adata_full.obs['drug'].str.contains(
    r"\bDMSO_TF\b|\bDMSO\b",  # matches "DMSO_TF" or "DMSO"
    case=False,
    na=False
)

# Prints total / control / treated counts and the percentage of controls.
print(f"Total cells: {len(ctrl_mask)}")
print(f"Control cells: {ctrl_mask.sum()}")
print(f"Treated cells: {(~ctrl_mask).sum()}")
print(f"Percentage controls: {ctrl_mask.mean()*100:.2f}%")
# control_percentage = ctrl_mask.mean()

# The treated cells are simply the inverse of the control mask:
treated_mask = ~ctrl_mask


# Collect all unique drug‐dose conditions (excluding controls) 
drug_conds = adata_full.obs.loc[treated_mask, "drugname_drugconc"].unique().tolist()  #Extracts all non-control conditions


# Stratified Subsampling of Treated Cells per Condition
N_per_drug = 500                                    #<--------choose the number N of cells per drug you want to keep!
expected_total_cells = N_per_drug * len(drug_conds)    
actual_total_cells = 0
N_ctrl = N_per_drug * len(drug_conds) 
N_ctrl = int(np.ceil(N_ctrl))
print(f"Sampling {N_ctrl} controls...")

# Stratified sampling for treated cells 
print("-> Sampling conditions...")
sampled_idxs = []
for index, cond in enumerate(drug_conds):
    idxs_tuple = np.where(adata_full.obs["drugname_drugconc"] == cond)
    idxs = idxs_tuple[0]
    n_to_pick  = min(len(idxs), N_per_drug)
    pick = np.random.choice(idxs, size=n_to_pick, replace=False)   #(replace=False) to keep unique cells
    sampled_idxs.append(pick)
    actual_total_cells += n_to_pick
    print(f'{index+1:2d}) {cond:>{45}} n_of_cells: {len(idxs):7d} n_to_pick: {n_to_pick}...')
print("Done.")
print(f"Total cells sampled: {actual_total_cells}, expected: {expected_total_cells}")

# Random sampling of DMSO controls 
print("-> Sampling controls...")
ctrl_idxs = np.where(ctrl_mask)[0]
n_to_pick = min(len(ctrl_idxs), N_ctrl)
ctrl_pick = np.random.choice(ctrl_idxs, size=n_to_pick, replace=False)
sampled_idxs.append(ctrl_pick)
print("Done.")
print(f"Total control sampled: {len(ctrl_pick)}, expected: {N_ctrl}")

# Combine all sampled indices and load subset into memory 
print("-> Loading subset into memory...")          
all_idxs   = np.concatenate(sampled_idxs)
adata_sub  = adata_full[all_idxs, :].to_memory()
print("Subset shape:", adata_sub.shape)
# Out:
# Local file 'plate9_full.h5ad' already exists; skipping download.
# Reading all data...
# -> Total cells on Plate 9: 5866669
#                        sample  gene_count  tscp_count  mread_count  \
# BARCODE_SUB_LIB_ID
# 01_001_019-lib_1585  smp_2263        1079        1464         1725
# 01_001_031-lib_1585  smp_2263        1122        1476         1771
# 01_001_132-lib_1585  smp_2263         977        1335         1577
# 01_001_133-lib_1585  smp_2263        2022        3251         3869
# 01_001_159-lib_1585  smp_2263        1178        1560         1823
#
#                                                      drugname_drugconc  \
# BARCODE_SUB_LIB_ID
# 01_001_019-lib_1585  [('Sivelestat (sodium tetrahydrate)', 5.0, 'uM')]
# 01_001_031-lib_1585  [('Sivelestat (sodium tetrahydrate)', 5.0, 'uM')]
# 01_001_132-lib_1585  [('Sivelestat (sodium tetrahydrate)', 5.0, 'uM')]
# 01_001_133-lib_1585  [('Sivelestat (sodium tetrahydrate)', 5.0, 'uM')]
# 01_001_159-lib_1585  [('Sivelestat (sodium tetrahydrate)', 5.0, 'uM')]
#
#                                                  drug  cell_line sublibrary  \
# BARCODE_SUB_LIB_ID
# 01_001_019-lib_1585  Sivelestat (sodium tetrahydrate)  CVCL_1098   lib_1585
# 01_001_031-lib_1585  Sivelestat (sodium tetrahydrate)  CVCL_0131   lib_1585
# 01_001_132-lib_1585  Sivelestat (sodium tetrahydrate)  CVCL_1478   lib_1585
# 01_001_133-lib_1585  Sivelestat (sodium tetrahydrate)  CVCL_0366   lib_1585
# 01_001_159-lib_1585  Sivelestat (sodium tetrahydrate)  CVCL_0428   lib_1585
#
#                         BARCODE  pcnt_mito   S_score  G2M_score phase  \
# BARCODE_SUB_LIB_ID
# 01_001_019-lib_1585  01_001_019   0.021175 -0.009524  -0.062109    G1
# 01_001_031-lib_1585  01_001_031   0.033875 -0.109524  -0.090817    G1
# 01_001_132-lib_1585  01_001_132   0.030712 -0.161905  -0.124218    G1
# 01_001_133-lib_1585  01_001_133   0.024915 -0.104762  -0.143265    G1
# 01_001_159-lib_1585  01_001_159   0.019231 -0.066667  -0.085756    G1
#
#                     pass_filter   cell_name   plate
# BARCODE_SUB_LIB_ID
# 01_001_019-lib_1585        full   HepG2/C3A  plate9
# 01_001_031-lib_1585        full       A-172  plate9
# 01_001_132-lib_1585        full   NCI-H1573  plate9
# 01_001_133-lib_1585        full     SNU-423  plate9
# 01_001_159-lib_1585        full  MIA PaCa-2  plate9
# Index(['sample', 'gene_count', 'tscp_count', 'mread_count',
#        'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE',
#        'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter',
#        'cell_name', 'plate'],
#       dtype='object')
# ------ All drug labels -------
# Total cells: 5866669
# Control cells: 183118
# Treated cells: 5683551
# Percentage controls: 3.12%
# Sampling 46500 controls...
# -> Sampling conditions...
#  1) [('Sivelestat (sodium tetrahydrate)', 5.0, 'uM')] n_of_cells:  123102 n_to_pick: 500...
#  2)                 [('Posaconazole', 5.0, 'uM')] n_of_cells:  118566 n_to_pick: 500...
#  3) [('Tetracycline (hydrochloride)', 5.0, 'uM')] n_of_cells:  110667 n_to_pick: 500...
#  4)      [('Entecavir (monohydrate)', 5.0, 'uM')] n_of_cells:  125435 n_to_pick: 500...
#  5)                   [('Sildenafil', 5.0, 'uM')] n_of_cells:  116963 n_to_pick: 500...
#  6)            [('Dimethyl fumarate', 5.0, 'uM')] n_of_cells:  103274 n_to_pick: 500...
#  7)  [('Berbamine (dihydrochloride)', 5.0, 'uM')] n_of_cells:   90258 n_to_pick: 500...
#  8)                      [('Daidzin', 5.0, 'uM')] n_of_cells:  101740 n_to_pick: 500...
#  9)                 [('Fumaric acid', 5.0, 'uM')] n_of_cells:  103965 n_to_pick: 500...
# 10)         [('Pravastatin (sodium)', 5.0, 'uM')] n_of_cells:  123514 n_to_pick: 500...
# 11)      [('Almonertinib (mesylate)', 5.0, 'uM')] n_of_cells:  133734 n_to_pick: 500...
# 12)   [('Irinotecan (hydrochloride)', 5.0, 'uM')] n_of_cells:   86788 n_to_pick: 500...
# 13)        [('Rucaparib (phosphate)', 5.0, 'uM')] n_of_cells:  131567 n_to_pick: 500...
# 14)                   [('crizotinib', 5.0, 'uM')] n_of_cells:   61799 n_to_pick: 500...
# 15)                   [('Dinaciclib', 5.0, 'uM')] n_of_cells:   12642 n_to_pick: 500...
# 16)           [('Bosentan (hydrate)', 5.0, 'uM')] n_of_cells:   28087 n_to_pick: 500...
# 17)                     [('Bestatin', 5.0, 'uM')] n_of_cells:   60369 n_to_pick: 500...
# 18)                    [('Tadalafil', 5.0, 'uM')] n_of_cells:   38875 n_to_pick: 500...
# 19)                  [('Belumosudil', 5.0, 'uM')] n_of_cells:   49360 n_to_pick: 500...
# 20)        [('Flumatinib (mesylate)', 5.0, 'uM')] n_of_cells:   59116 n_to_pick: 500...
# 21)                   [('Cytarabine', 5.0, 'uM')] n_of_cells:   36113 n_to_pick: 500...
# 22)                     [('Afatinib', 5.0, 'uM')] n_of_cells:   43829 n_to_pick: 500...
# 23)    [('Topotecan (hydrochloride)', 5.0, 'uM')] n_of_cells:   27170 n_to_pick: 500...
# 24)                     [('Naproxen', 5.0, 'uM')] n_of_cells:   47462 n_to_pick: 500...
# 25)                   [('Lucanthone', 5.0, 'uM')] n_of_cells:   76064 n_to_pick: 500...
# 26)     [('Benproperine (phosphate)', 5.0, 'uM')] n_of_cells:   51931 n_to_pick: 500...
# 27)                    [('Erlotinib', 5.0, 'uM')] n_of_cells:   47066 n_to_pick: 500...
# 28)                  [('Fenofibrate', 5.0, 'uM')] n_of_cells:   51939 n_to_pick: 500...
# 29)               [('(S)-Crizotinib', 5.0, 'uM')] n_of_cells:   58891 n_to_pick: 500...
# 30)           [('Rutin (trihydrate)', 5.0, 'uM')] n_of_cells:   51107 n_to_pick: 500...
# 31) [('Pexidartinib (hydrochloride)', 5.0, 'uM')] n_of_cells:   72599 n_to_pick: 500...
# 32)                 [('Tirabrutinib', 5.0, 'uM')] n_of_cells:   91592 n_to_pick: 500...
# 33)              [('Diphenhydramine', 5.0, 'uM')] n_of_cells:   60983 n_to_pick: 500...
# 34)                [('Harringtonine', 5.0, 'uM')] n_of_cells:  101490 n_to_pick: 500...
# 35)   [('Epirubicin (hydrochloride)', 5.0, 'uM')] n_of_cells:   66113 n_to_pick: 500...
# 36)           [('Phenytoin (sodium)', 5.0, 'uM')] n_of_cells:   61175 n_to_pick: 500...
# 37)                     [('Orlistat', 5.0, 'uM')] n_of_cells:   74326 n_to_pick: 500...
# 38)         [('Sacubitril/Valsartan', 5.0, 'uM')] n_of_cells:   65430 n_to_pick: 500...
# 39)                [('Monocrotaline', 5.0, 'uM')] n_of_cells:   50560 n_to_pick: 500...
# 40)                  [('Finasteride', 5.0, 'uM')] n_of_cells:   51251 n_to_pick: 500...
# 41)                  [('Hydroxyurea', 5.0, 'uM')] n_of_cells:   60345 n_to_pick: 500...
# 42)    [('Doxycycline (monohydrate)', 5.0, 'uM')] n_of_cells:   41982 n_to_pick: 500...
# 43)       [('Pitavastatin (Calcium)', 5.0, 'uM')] n_of_cells:   30243 n_to_pick: 500...
# 44)                  [('Cobimetinib', 5.0, 'uM')] n_of_cells:   35863 n_to_pick: 500...
# 45)                    [('Simotinib', 5.0, 'uM')] n_of_cells:   26141 n_to_pick: 500...
# 46) [('Procainamide (hydrochloride)', 5.0, 'uM')] n_of_cells:   48682 n_to_pick: 500...
# 47)                    [('Silodosin', 5.0, 'uM')] n_of_cells:   36761 n_to_pick: 500...
# 48)                   [('Nevirapine', 5.0, 'uM')] n_of_cells:   72654 n_to_pick: 500...
# 49)                   [('Cilostazol', 5.0, 'uM')] n_of_cells:   68578 n_to_pick: 500...
# 50)  [('Dorzolamide (hydrochloride)', 5.0, 'uM')] n_of_cells:   62616 n_to_pick: 500...
# 51)                   [('Roxadustat', 5.0, 'uM')] n_of_cells:   59790 n_to_pick: 500...
# 52)                [('Canagliflozin', 5.0, 'uM')] n_of_cells:   35899 n_to_pick: 500...
# 53)                   [('Decitabine', 5.0, 'uM')] n_of_cells:   63066 n_to_pick: 500...
# 54)                 [('Ligustrazine', 5.0, 'uM')] n_of_cells:   40701 n_to_pick: 500...
# 55)                  [('Thymopentin', 5.0, 'uM')] n_of_cells:   47584 n_to_pick: 500...
# 56)                  [('Verteporfin', 5.0, 'uM')] n_of_cells:   38053 n_to_pick: 500...
# 57)                   [('Hesperidin', 5.0, 'uM')] n_of_cells:   43834 n_to_pick: 500...
# 58)                  [('Mebendazole', 5.0, 'uM')] n_of_cells:  127048 n_to_pick: 500...
# 59)   [('Betamethasone dipropionate', 5.0, 'uM')] n_of_cells:   74580 n_to_pick: 500...
# 60) [('Levobupivacaine (hydrochloride)', 5.0, 'uM')] n_of_cells:   54885 n_to_pick: 500...
# 61)                [('Rosiglitazone', 5.0, 'uM')] n_of_cells:   41368 n_to_pick: 500...
# 62) [('Quinidine (15% dihydroquinidine)', 5.0, 'uM')] n_of_cells:   54860 n_to_pick: 500...
# 63)                    [('Verapamil', 5.0, 'uM')] n_of_cells:   65555 n_to_pick: 500...
# 64)    [('Bisoprolol (hemifumarate)', 5.0, 'uM')] n_of_cells:   54114 n_to_pick: 500...
# 65)                  [('Penfluridol', 5.0, 'uM')] n_of_cells:   34179 n_to_pick: 500...
# 66)                 [('Ferulic acid', 5.0, 'uM')] n_of_cells:   45293 n_to_pick: 500...
# 67)                   [('Pemetrexed', 5.0, 'uM')] n_of_cells:   28942 n_to_pick: 500...
# 68)                  [('Fluvoxamine', 5.0, 'uM')] n_of_cells:   43167 n_to_pick: 500...
# 69)   [('Cytarabine (hydrochloride)', 5.0, 'uM')] n_of_cells:   53185 n_to_pick: 500...
# 70)                 [('Bendamustine', 5.0, 'uM')] n_of_cells:   38831 n_to_pick: 500...
# 71)                  [('Altretamine', 5.0, 'uM')] n_of_cells:   57717 n_to_pick: 500...
# 72)                    [('Rifaximin', 5.0, 'uM')] n_of_cells:   51069 n_to_pick: 500...
# 73)              [('Dexmedetomidine', 5.0, 'uM')] n_of_cells:   59302 n_to_pick: 500...
# 74)  [('Doxorubicin (hydrochloride)', 5.0, 'uM')] n_of_cells:   35217 n_to_pick: 500...
# 75)                    [('Menadione', 5.0, 'uM')] n_of_cells:   37226 n_to_pick: 500...
# 76)            [('Glycyrrhizic acid', 5.0, 'uM')] n_of_cells:   61458 n_to_pick: 500...
# 77) [('Dapagliflozin ((2S)-1,2-propanediol, hydrate)', 5.0, 'uM')] n_of_cells:   50760 n_to_pick: 500...
# 78)          [('Imiquimod (maleate)', 5.0, 'uM')] n_of_cells:   31318 n_to_pick: 500...
# 79)                  [('Clofarabine', 5.0, 'uM')] n_of_cells:   37441 n_to_pick: 500...
# 80)                   [('Mozavaptan', 5.0, 'uM')] n_of_cells:   41626 n_to_pick: 500...
# 81)                    [('Adagrasib', 5.0, 'uM')] n_of_cells:   77265 n_to_pick: 500...
# 82)                   [('Sulfatinib', 5.0, 'uM')] n_of_cells:   75707 n_to_pick: 500...
# 83)                      [('Arbutin', 5.0, 'uM')] n_of_cells:   64685 n_to_pick: 500...
# 84)       [('Docetaxel (Trihydrate)', 5.0, 'uM')] n_of_cells:   54793 n_to_pick: 500...
# 85)                    [('Tranilast', 5.0, 'uM')] n_of_cells:   70196 n_to_pick: 500...
# 86)                   [('Macitentan', 5.0, 'uM')] n_of_cells:   38276 n_to_pick: 500...
# 87)                   [('Eplerenone', 5.0, 'uM')] n_of_cells:   69291 n_to_pick: 500...
# 88)                 [('Mifepristone', 5.0, 'uM')] n_of_cells:   56697 n_to_pick: 500...
# 89)                  [('Apalutamide', 5.0, 'uM')] n_of_cells:   47538 n_to_pick: 500...
# 90)        [('Niclosamide (olamine)', 5.0, 'uM')] n_of_cells:   24306 n_to_pick: 500...
# 91)                   [('Peretinoin', 5.0, 'uM')] n_of_cells:   42161 n_to_pick: 500...
# 92)                     [('Tolmetin', 5.0, 'uM')] n_of_cells:   52929 n_to_pick: 500...
# 93)                   [('Adagrasib', 0.05, 'uM')] n_of_cells:   50862 n_to_pick: 500...
# Done.
# Total cells sampled: 46500, expected: 46500
# -> Sampling controls...
# Done.
# Total control sampled: 46500, expected: 46500
# -> Loading subset into memory...
# Subset shape: (93000, 62710)

# %% [markdown]
# # Data Preprocessing for CPA

# %% [markdown]
# ### Preprocessing AnnData for CPA: Raw Counts, Dose Extraction, Filtering, Normalization, and HVG Selection

# %%
# Create a Copy & Save Raw Counts for normalizing and log-transforming
print(adata_sub)
adata_sub_log = adata_sub.copy()
adata_sub_log.layers['counts'] = adata_sub_log.X.copy()

print("\nCells per drug condition:")
print(adata_sub_log.obs["drugname_drugconc"].value_counts())

# Define CPA-Specific Observation Keys
adata_sub_log.obs["condition_ID"] = adata_sub_log.obs["drugname_drugconc"].apply(parse_condition)
print("\nCondition IDs:\n", adata_sub_log.obs["condition_ID"])

# Extract numeric dose (µM) from strings
adata_sub_log.obs["dose"] = adata_sub_log.obs["drugname_drugconc"].apply(get_dose_from_condition)

print("\nDoses (µM):\n", adata_sub_log.obs["dose"])

adata_sub_log.obs['log_dose'] = np.log10(adata_sub_log.obs['dose'] + 1e-6)
print("\nLog - Doses (µM):\n", adata_sub_log.obs["log_dose"])

# Filter out cells with low number of counts
before = adata_sub_log.n_obs
sc.pp.filter_cells(adata_sub_log, min_counts=100)
after = adata_sub_log.n_obs
print(f"➡️ Filtered cells based on min_counts ≥ 100:")
print(f"   • Before filtering: {before} cells")
print(f"   • After filtering:  {after} cells")
print(f"   • Cells removed:    {before - after}")

print("\n ➜ Sample of remaining cells:")
print(adata_sub_log.obs.head())

# Normalize counts to 10k UMIs per cell
print("-> Normalizing...")
sc.pp.normalize_total(adata_sub_log, target_sum=1e4, exclude_highly_expressed=True)

# Log-transform
print("-> Log transforming...")
sc.pp.log1p(adata_sub_log)

# Select HVGs (2 000 genes)
print("-> Highly Variable Genes...")
sc.pp.highly_variable_genes(adata_sub_log, n_top_genes=2000, subset=True)
# Out:
# AnnData object with n_obs × n_vars = 93000 × 62710
#     obs: 'sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate'
#
# Cells per drug condition:
# drugname_drugconc
# [('DMSO_TF', 0.0, 'uM')]                         33600
# [('Trametinib (DMSO_TF solvate)', 5.0, 'uM')]    12900
# [('Adagrasib', 0.05, 'uM')]                        500
# [('Afatinib', 5.0, 'uM')]                          500
# [('Almonertinib (mesylate)', 5.0, 'uM')]           500
#                                                  ...
# [('Topotecan (hydrochloride)', 5.0, 'uM')]         500
# [('Tranilast', 5.0, 'uM')]                         500
# [('Verapamil', 5.0, 'uM')]                         500
# [('Verteporfin', 5.0, 'uM')]                       500
# [('crizotinib', 5.0, 'uM')]                        500
# Name: count, Length: 95, dtype: int64
#
# Condition IDs:
#  BARCODE_SUB_LIB_ID
# 01_166_159-lib_1645    Sivelestat (sodium tetrahydrate)_50uM
# 01_001_005-lib_2504    Sivelestat (sodium tetrahydrate)_50uM
# 01_015_109-lib_1647    Sivelestat (sodium tetrahydrate)_50uM
# 01_093_083-lib_1592    Sivelestat (sodium tetrahydrate)_50uM
# 01_149_149-lib_1632    Sivelestat (sodium tetrahydrate)_50uM
#                                        ...
# 95_153_126-lib_1617                             DMSO_TF_00uM
# 95_080_006-lib_1669                             DMSO_TF_00uM
# 96_078_175-lib_2498                             DMSO_TF_00uM
# 95_137_187-lib_1604                             DMSO_TF_00uM
# 95_029_030-lib_1590                             DMSO_TF_00uM
# Name: condition_ID, Length: 93000, dtype: category
# Categories (95, object): ['(S)-Crizotinib_50uM', 'Adagrasib_005uM', 'Adagrasib_50uM', 'Afatinib_50uM', ..., 'Tranilast_50uM', 'Verapamil_50uM', 'Verteporfin_50uM', 'crizotinib_50uM']
#
# Doses (µM):
#  BARCODE_SUB_LIB_ID
# 01_166_159-lib_1645    5.0
# 01_001_005-lib_2504    5.0
# 01_015_109-lib_1647    5.0
# 01_093_083-lib_1592    5.0
# 01_149_149-lib_1632    5.0
#                       ...
# 95_153_126-lib_1617    0.0
# 95_080_006-lib_1669    0.0
# 96_078_175-lib_2498    0.0
# 95_137_187-lib_1604    0.0
# 95_029_030-lib_1590    0.0
# Name: dose, Length: 93000, dtype: float64
#
# Log - Doses (µM):
#  BARCODE_SUB_LIB_ID
# 01_166_159-lib_1645    0.69897
# 01_001_005-lib_2504    0.69897
# 01_015_109-lib_1647    0.69897
# 01_093_083-lib_1592    0.69897
# 01_149_149-lib_1632    0.69897
#                         ...
# 95_153_126-lib_1617   -6.00000
# 95_080_006-lib_1669   -6.00000
# 96_078_175-lib_2498   -6.00000
# 95_137_187-lib_1604   -6.00000
# 95_029_030-lib_1590   -6.00000
# Name: log_dose, Length: 93000, dtype: float64
# ➡️ Filtered cells based on min_counts ≥ 100:
#    • Before filtering: 93000 cells
#    • After filtering:  93000 cells
#    • Cells removed:    0
#
#  ➜ Sample of remaining cells:
#                        sample  gene_count  tscp_count  mread_count  \
# BARCODE_SUB_LIB_ID
# 01_166_159-lib_1645  smp_2263         647         827          966
# 01_001_005-lib_2504  smp_2263        2167        3243         3820
# 01_015_109-lib_1647  smp_2263        1027        1438         1687
# 01_093_083-lib_1592  smp_2263         791        1010         1172
# 01_149_149-lib_1632  smp_2263         873        1294         1498
#
#                                                      drugname_drugconc  \
# BARCODE_SUB_LIB_ID
# 01_166_159-lib_1645  [('Sivelestat (sodium tetrahydrate)', 5.0, 'uM')]
# 01_001_005-lib_2504  [('Sivelestat (sodium tetrahydrate)', 5.0, 'uM')]
# 01_015_109-lib_1647  [('Sivelestat (sodium tetrahydrate)', 5.0, 'uM')]
# 01_093_083-lib_1592  [('Sivelestat (sodium tetrahydrate)', 5.0, 'uM')]
# 01_149_149-lib_1632  [('Sivelestat (sodium tetrahydrate)', 5.0, 'uM')]
#
#                                                  drug  cell_line sublibrary  \
# BARCODE_SUB_LIB_ID
# 01_166_159-lib_1645  Sivelestat (sodium tetrahydrate)  CVCL_0332   lib_1645
# 01_001_005-lib_2504  Sivelestat (sodium tetrahydrate)  CVCL_1495   lib_2504
# 01_015_109-lib_1647  Sivelestat (sodium tetrahydrate)  CVCL_0480   lib_1647
# 01_093_083-lib_1592  Sivelestat (sodium tetrahydrate)  CVCL_1239   lib_1592
# 01_149_149-lib_1632  Sivelestat (sodium tetrahydrate)  CVCL_0152   lib_1632
#
#                         BARCODE  pcnt_mito   S_score  G2M_score phase  \
# BARCODE_SUB_LIB_ID
# 01_166_159-lib_1645  01_166_159   0.008464 -0.066667  -0.009293    G1
# 01_001_005-lib_2504  01_001_005   0.034844 -0.161905  -0.183608    G1
# 01_015_109-lib_1647  01_015_109   0.058414 -0.100000  -0.061538    G1
# 01_093_083-lib_1592  01_093_083   0.015842 -0.029331  -0.052381    G1
# 01_149_149-lib_1632  01_149_149   0.032457 -0.095238  -0.076007    G1
#
#                     pass_filter  cell_name   plate  \
# BARCODE_SUB_LIB_ID
# 01_166_159-lib_1645        full    HS-578T  plate9
# 01_001_005-lib_2504        full  NCI-H1792  plate9
# 01_015_109-lib_1647        full     PANC-1  plate9
# 01_093_083-lib_1592        full         H4  plate9
# 01_149_149-lib_1632        full     AsPC-1  plate9
#
#                                               condition_ID  dose  log_dose  \
# BARCODE_SUB_LIB_ID
# 01_166_159-lib_1645  Sivelestat (sodium tetrahydrate)_50uM   5.0   0.69897
# 01_001_005-lib_2504  Sivelestat (sodium tetrahydrate)_50uM   5.0   0.69897
# 01_015_109-lib_1647  Sivelestat (sodium tetrahydrate)_50uM   5.0   0.69897
# 01_093_083-lib_1592  Sivelestat (sodium tetrahydrate)_50uM   5.0   0.69897
# 01_149_149-lib_1632  Sivelestat (sodium tetrahydrate)_50uM   5.0   0.69897
#
#                      n_counts
# BARCODE_SUB_LIB_ID
# 01_166_159-lib_1645     827.0
# 01_001_005-lib_2504    3243.0
# 01_015_109-lib_1647    1438.0
# 01_093_083-lib_1592    1010.0
# 01_149_149-lib_1632    1294.0
# -> Normalizing...
# -> Log transforming...
# -> Highly Variable Genes...

# %% [markdown]
# ### Marking Control vs Stimulated Cells and Computing Differential Expression (DE) per Cell Line

# %%
# Mark DMSO_TF as control vs stimulated cells
adata_sub_log.obs['condition'] = adata_sub_log.obs['condition_ID'].apply(lambda x: 'ctrl' if 'DMSO_TF_' in str(x) else 'stimulated')

# Observe condition counts  and columns
print("\n=== condition value counts ===")
print(adata_sub_log.obs['condition'].value_counts())
print(adata_sub_log.obs.columns.tolist())
print(adata_sub_log.obs.head())

# Create Combined Covariate Column
adata_sub_log.obs['cov_cond'] = adata_sub_log.obs['cell_line'].astype(str) + '_' + adata_sub_log.obs['condition'].astype(str)

# Store Raw Counts for DE Analysis               
adata_sub_log.raw = adata_sub_log   

# Prepare for DE Analysis
adata_sub_log.uns['rank_genes_groups'] = {}
cell_lines = adata_sub_log.obs['cell_line'].unique()

# Loop Over Cell Lines and Compute DEGs
for cell in cell_lines:
    adata_cell = adata_sub_log[adata_sub_log.obs['cell_line'] == cell].copy()

    # Skips cell lines without both control and stimulated groups.
    cond_counts = adata_cell.obs['condition'].value_counts()
    if not {'ctrl', 'stimulated'}.issubset(cond_counts.index):
        print(f"⏭ Skipping {cell}: missing ctrl or stimulated")
        continue
    if cond_counts['ctrl'] < 2 or cond_counts['stimulated'] < 2:
        print(f" Skipping {cell}: not enough cells per group (ctrl={cond_counts['ctrl']}, stim={cond_counts['stimulated']})")
        continue

    #adata_cell.raw = adata_cell

    # Run DE analysis:
    sc.tl.rank_genes_groups(
        adata_cell,
        groupby='condition',
        reference='ctrl',
        method='t-test_overestim_var',
        use_raw=True
    )

    key = f"{cell}_stimulated"   # Save DE results for this cell line
    adata_sub_log.uns['rank_genes_groups'][key] = {k: v['stimulated'] for k, v in adata_cell.uns['rank_genes_groups'].items() if isinstance(v, np.ndarray)}

print(" Finished computing per-cell-line DEGs.")


# Save downsampled, preprocessed Data  
save_path = "plate9_preprocessed_for_CPA_pred_cell_1.h5ad"               
adata_sub_log.write_h5ad(save_path)
print(f"Wrote fully preprocessed AnnData to: {save_path}")
# Out:
# === condition value counts ===
# condition
# stimulated    59400
# ctrl          33600
# Name: count, dtype: int64
# ['sample', 'gene_count', 'tscp_count', 'mread_count', 'drugname_drugconc', 'drug', 'cell_line', 'sublibrary', 'BARCODE', 'pcnt_mito', 'S_score', 'G2M_score', 'phase', 'pass_filter', 'cell_name', 'plate', 'condition_ID', 'dose', 'log_dose', 'n_counts', 'condition']
#                        sample  gene_count  tscp_count  mread_count  \
# BARCODE_SUB_LIB_ID
# 01_166_159-lib_1645  smp_2263         647         827          966
# 01_001_005-lib_2504  smp_2263        2167        3243         3820
# 01_015_109-lib_1647  smp_2263        1027        1438         1687
# 01_093_083-lib_1592  smp_2263         791        1010         1172
# 01_149_149-lib_1632  smp_2263         873        1294         1498
#
#                                                      drugname_drugconc  \
# BARCODE_SUB_LIB_ID
# 01_166_159-lib_1645  [('Sivelestat (sodium tetrahydrate)', 5.0, 'uM')]
# 01_001_005-lib_2504  [('Sivelestat (sodium tetrahydrate)', 5.0, 'uM')]
# 01_015_109-lib_1647  [('Sivelestat (sodium tetrahydrate)', 5.0, 'uM')]
# 01_093_083-lib_1592  [('Sivelestat (sodium tetrahydrate)', 5.0, 'uM')]
# 01_149_149-lib_1632  [('Sivelestat (sodium tetrahydrate)', 5.0, 'uM')]
#
#                                                  drug  cell_line sublibrary  \
# BARCODE_SUB_LIB_ID
# 01_166_159-lib_1645  Sivelestat (sodium tetrahydrate)  CVCL_0332   lib_1645
# 01_001_005-lib_2504  Sivelestat (sodium tetrahydrate)  CVCL_1495   lib_2504
# 01_015_109-lib_1647  Sivelestat (sodium tetrahydrate)  CVCL_0480   lib_1647
# 01_093_083-lib_1592  Sivelestat (sodium tetrahydrate)  CVCL_1239   lib_1592
# 01_149_149-lib_1632  Sivelestat (sodium tetrahydrate)  CVCL_0152   lib_1632
#
#                         BARCODE  pcnt_mito  ...  G2M_score  phase pass_filter  \
# BARCODE_SUB_LIB_ID                          ...
# 01_166_159-lib_1645  01_166_159   0.008464  ...  -0.009293     G1        full
# 01_001_005-lib_2504  01_001_005   0.034844  ...  -0.183608     G1        full
# 01_015_109-lib_1647  01_015_109   0.058414  ...  -0.061538     G1        full
# 01_093_083-lib_1592  01_093_083   0.015842  ...  -0.052381     G1        full
# 01_149_149-lib_1632  01_149_149   0.032457  ...  -0.076007     G1        full
#
#                      cell_name   plate                           condition_ID  \
# BARCODE_SUB_LIB_ID
# 01_166_159-lib_1645    HS-578T  plate9  Sivelestat (sodium tetrahydrate)_50uM
# 01_001_005-lib_2504  NCI-H1792  plate9  Sivelestat (sodium tetrahydrate)_50uM
# 01_015_109-lib_1647     PANC-1  plate9  Sivelestat (sodium tetrahydrate)_50uM
# 01_093_083-lib_1592         H4  plate9  Sivelestat (sodium tetrahydrate)_50uM
# 01_149_149-lib_1632     AsPC-1  plate9  Sivelestat (sodium tetrahydrate)_50uM
#
#                     dose  log_dose  n_counts   condition
# BARCODE_SUB_LIB_ID
# 01_166_159-lib_1645  5.0   0.69897     827.0  stimulated
# 01_001_005-lib_2504  5.0   0.69897    3243.0  stimulated
# 01_015_109-lib_1647  5.0   0.69897    1438.0  stimulated
# 01_093_083-lib_1592  5.0   0.69897    1010.0  stimulated
# 01_149_149-lib_1632  5.0   0.69897    1294.0  stimulated
#
# [5 rows x 21 columns]
#  Finished computing per-cell-line DEGs.
# Wrote fully preprocessed AnnData to: plate9_preprocessed_for_CPA_pred_cell_1.h5ad

# %%
print(adata_sub_log.obs[['cell_line', 'cell_name']].head(50))
# Out:
#                      cell_line   cell_name
# BARCODE_SUB_LIB_ID
# 01_166_159-lib_1645  CVCL_0332     HS-578T
# 01_001_005-lib_2504  CVCL_1495   NCI-H1792
# 01_015_109-lib_1647  CVCL_0480      PANC-1
# 01_093_083-lib_1592  CVCL_1239          H4
# 01_149_149-lib_1632  CVCL_0152      AsPC-1
# 01_052_137-lib_1617  CVCL_1119     CFPAC-1
# 01_015_002-lib_1593  CVCL_1055       A-427
# 01_060_106-lib_1670  CVCL_0292       HCT15
# 01_164_152-lib_1669  CVCL_1693      SHP-77
# 01_062_162-lib_1647  CVCL_0504         RKO
# 01_085_079-lib_2507  CVCL_0293     HEC-1-A
# 01_031_148-lib_1597  CVCL_1731      SW 900
# 01_132_144-lib_1643  CVCL_0480      PANC-1
# 01_002_191-lib_2608  CVCL_0428  MIA PaCa-2
# 01_177_033-lib_1639  CVCL_1097         C32
# 01_029_148-lib_1650  CVCL_0152      AsPC-1
# 01_119_077-lib_1626  CVCL_C466  hTERT-HPNE
# 01_074_127-lib_1667  CVCL_1056        A498
# 01_025_087-lib_1613  CVCL_0504         RKO
# 01_096_120-lib_2504  CVCL_1381    LOX-IMVI
# 01_124_188-lib_1665  CVCL_0546       SW480
# 01_119_104-lib_1678  CVCL_0480      PANC-1
# 01_005_158-lib_1656  CVCL_1495   NCI-H1792
# 01_124_151-lib_1675  CVCL_0480      PANC-1
# 01_187_069-lib_1640  CVCL_0399        LoVo
# 01_051_136-lib_1654  CVCL_0371    KATO III
# 01_183_020-lib_2507  CVCL_0069    SK-MEL-2
# 01_034_061-lib_1603  CVCL_1717      SW1417
# 01_181_096-lib_1593  CVCL_0320       HT-29
# 01_167_094-lib_1611  CVCL_0546       SW480
# 01_119_112-lib_1649  CVCL_1517   NCI-H2030
# 01_006_103-lib_1615  CVCL_0359         J82
# 01_024_177-lib_1652  CVCL_1717      SW1417
# 01_152_130-lib_2508  CVCL_0371    KATO III
# 01_072_102-lib_1640  CVCL_1693      SHP-77
# 01_034_053-lib_1620  CVCL_1285       HOP62
# 01_108_142-lib_1593  CVCL_0546       SW480
# 01_134_171-lib_1603  CVCL_0371    KATO III
# 01_098_113-lib_1614  CVCL_0069    SK-MEL-2
# 01_015_135-lib_1621  CVCL_1055       A-427
# 01_111_172-lib_1656  CVCL_0480      PANC-1
# 01_090_150-lib_1652  CVCL_0546       SW480
# 01_171_145-lib_1649  CVCL_0459    NCI-H460
# 01_160_172-lib_1613  CVCL_0480      PANC-1
# 01_116_054-lib_1680  CVCL_0480      PANC-1
# 01_139_134-lib_1640  CVCL_0366     SNU-423
# 01_178_163-lib_1637  CVCL_1119     CFPAC-1
# 01_046_011-lib_1663  CVCL_0428  MIA PaCa-2
# 01_030_173-lib_1658  CVCL_0320       HT-29
# 01_053_030-lib_1673  CVCL_0293     HEC-1-A
